# %%
import pandas as pd
import numpy as np

record = pd.read_pickle("../Data/main_1.df")
feats = ['actual_weight','declared_horse_weight','win_odds','jockey_ave_rank','trainer_ave_rank',
'recent_ave_rank','race_distance']
record.rename(columns={"declared_weight":"declared_horse_weight",
                        "distance":"race_distance",
                        "won":'HorseWin',
                      "jockey_id":"Jockey",
                      "trainer_id":"Trainer",
                      "horse_id":"HorseID",
                      "date":"RaceDate",
                      "result":"Pla"}, inplace=True)

# %%
for i in record.columns:
    print(i)
# Out:
# race_id
# horse_no
# HorseID
# Pla
# HorseWin
# lengths_behind
# horse_age
# horse_country
# horse_type
# horse_rating
# horse_gear
# declared_horse_weight
# actual_weight
# draw
# position_sec1
# position_sec2
# position_sec3
# position_sec4
# position_sec5
# position_sec6
# behind_sec1
# behind_sec2
# behind_sec3
# behind_sec4
# behind_sec5
# behind_sec6
# time1
# time2
# time3
# time4
# time5
# time6
# finish_time
# win_odds
# place_odds
# Trainer
# Jockey
# race_size
# RaceDate
# venue
# race_no
# race_distance
# going
# config
# horse_ratings
# prize
# race_class
# place_combination1
# place_combination2
# place_combination3
# place_combination4
# last_race_result
# win_percent
# avg_distance_time
# normal_avg_distance_time
# going_type
# going_type_record
# actual_weight_scaled
# declared_weight_scaled
# horse_race_count
# horse_type_Brown
# horse_type_Colt
# horse_type_Filly
# horse_type_Gelding
# horse_type_Grey
# horse_type_Horse
# horse_type_Mare
# horse_type_Rig
# horse_type_Roan
# horse_country_ARG
# horse_country_AUS
# horse_country_BRZ
# horse_country_CAN
# horse_country_FR
# horse_country_GB
# horse_country_GER
# horse_country_GR
# horse_country_IRE
# horse_country_ITY
# horse_country_JPN
# horse_country_NZ
# horse_country_SAF
# horse_country_SPA
# horse_country_USA
# horse_country_ZIM
# going_type_fast
# going_type_slow
# going_type_wet
# jockey_record
# trainer_record
# horse_record
# days_since_last_race
# weight_change
# weight_change_over_time
# weight_change_from_average
# weight_change_increase
# normalized_result
# venue_change
# venue_record
# best_odds
# best_win_percent
# best_distance_time
# best_going_record
# best_horse_record
# best_jockey_record
# best_trainer_record
# highest_actual_weight
# lowest_actual_weight
# new_horse
# start_speed
# surface
# surface_record
# rode_before
# placed
# jockey_ave_rank
# trainer_ave_rank
# recent_ave_rank

# %%
# Add jockey record
jockAvg = np.zeros(len(record))
jockey = np.unique(record["Jockey"])

for i in range(len(jockey)):
    temp = record[record.Jockey == jockey[i]]
    tempI = temp.index
    if (i%10)==0:
        print("{}/{}".format(i, len(jockey)))
    
    for j in range(len(temp)):
        temp_2 = temp.iloc[j,:]
        date = temp_2["RaceDate"]
        
        beforeRaces = temp.loc[temp["RaceDate"]<date]
        
        if beforeRaces.shape[0] != 0:
            jockAvg[tempI[j]] = np.mean(temp["Pla"])

record['jockey_ave_rank'] = jockAvg

trainAvg = np.zeros(len(record))
trainer = np.unique(record["Trainer"])

for i in range(len(trainer)):
    temp = record[record.Trainer == trainer[i]]
    tempI = temp.index
    if (i%10)==0:
        print("{}/{}".format(i, len(trainer)))
    
    for j in range(len(temp)):
        temp_2 = temp.iloc[j,:]
        date = temp_2["RaceDate"]
        
        beforeRaces = temp.loc[temp["RaceDate"]<date]
        
        if beforeRaces.shape[0] != 0:
            trainAvg[tempI[j]] = np.mean(temp["Pla"])

record['trainer_ave_rank'] = trainAvg

recent = np.zeros(len(record))

horses = np.unique(record["HorseID"])
for i in range(len(horses)):
    temp = record[record.HorseID == horses[i]]
    tempI = temp.index
    if (i%10)==0:
        print("{}/{}".format(i, len(horses)))
    
    for j in range(len(temp)):
        temp_2 = temp.iloc[j,:]
        date = temp_2["RaceDate"]
        
        beforeRaces = temp.loc[temp["RaceDate"]<date]
        
        if beforeRaces.shape[0] != 0:
            if beforeRaces.shape[0] <= 6:
                recent[tempI[j]] = np.mean(temp["Pla"])
            else:
                recent[tempI[j]] = np.mean(temp["Pla"][-6:])

record['recent_ave_rank'] = recent

# Add HorseWin
horseWin = np.zeros(len(record), dtype=int)

for i in range(len(record)):
    if record.iloc[i,:]["Pla"]==1:
        horseWin[i] = 1
        
record["HorseWin"] = horseWin
# Out:
# 0/186
# 10/186
# 20/186
# 30/186
# 40/186
# 50/186
# 60/186
# 70/186
# 80/186
# 90/186
# 100/186
# 110/186
# 120/186
# 130/186
# 140/186
# 150/186
# 160/186
# 170/186
# 180/186
# 0/176
# 10/176
# 20/176
# 30/176
# 40/176
# 50/176
# 60/176
# 70/176
# 80/176
# 90/176
# 100/176
# 110/176
# 120/176
# 130/176
# 140/176
# 150/176
# 160/176
# 170/176
# 0/4405
# 10/4405
# 20/4405
# 30/4405
# 40/4405
# 50/4405
# 60/4405
# 70/4405
# 80/4405
# 90/4405
# 100/4405
# 110/4405
# 120/4405
# 130/4405
# 140/4405
# 150/4405
# 160/4405
# 170/4405
# 180/4405
# 190/4405
# 200/4405
# 210/4405
# 220/4405
# 230/4405
# 240/4405
# 250/4405
# 260/4405
# 270/4405
# 280/4405
# 290/4405
# 300/4405
# 310/4405
# 320/4405
# 330/4405
# 340/4405
# 350/4405
# 360/4405
# 370/4405
# 380/4405
# 390/4405
# 400/4405
# 410/4405
# 420/4405
# 430/4405
# 440/4405
# 450/4405
# 460/4405
# 470/4405
# 480/4405
# 490/4405
# 500/4405
# 510/4405
# 520/4405
# 530/4405
# 540/4405
# 550/4405
# 560/4405
# 570/4405
# 580/4405
# 590/4405
# 600/4405
# 610/4405
# 620/4405
# 630/4405
# 640/4405
# 650/4405
# 660/4405
# 670/4405
# 680/4405
# 690/4405
# 700/4405
# 710/4405
# 720/4405
# 730/4405
# 740/4405
# 750/4405
# 760/4405
# 770/4405
# 780/4405
# 790/4405
# 800/4405
# 810/4405
# 820/4405
# 830/4405
# 2660/4405
# 2670/4405
# 2680/4405
# 2690/4405
# 2700/4405
# 2710/4405
# 2720/4405
# 2730/4405
# 2740/4405
# 2750/4405
# 2760/4405
# 2770/4405
# 2780/4405
# 2790/4405
# 2800/4405
# 2810/4405
# 2820/4405
# 2830/4405
# 2840/4405
# 2850/4405
# 2860/4405
# 2870/4405
# 2880/4405
# 2890/4405
# 2900/4405
# 2910/4405
# 2920/4405
# 2930/4405
# 2940/4405
# 2950/4405
# 2960/4405
# 2970/4405
# 2980/4405
# 2990/4405
# 3000/4405
# 3010/4405
# 3020/4405
# 3030/4405
# 3040/4405
# 3050/4405
# 3060/4405
# 3070/4405
# 3080/4405
# 3090/4405
# 3100/4405
# 3110/4405
# 3120/4405
# 3130/4405
# 3140/4405
# 3150/4405
# 3160/4405
# 3170/4405
# 3180/4405
# 3190/4405
# 3200/4405
# 3210/4405
# 3220/4405
# 3230/4405
# 3240/4405
# 3250/4405
# 3260/4405
# 3270/4405
# 3280/4405
# 3290/4405
# 3300/4405
# 3310/4405
# 3320/4405
# 3330/4405
# 3340/4405
# 3350/4405
# 3360/4405
# 3370/4405
# 3380/4405
# 3390/4405
# 3400/4405
# 3410/4405
# 3420/4405
# 3430/4405
# 3440/4405
# 3450/4405
# 3460/4405
# 3470/4405
# 3480/4405
# 3490/4405
# 3500/4405
# 3510/4405
# 3520/4405
# 3530/4405
# 3540/4405
# 3550/4405
# 3560/4405
# 3570/4405
# 3580/4405
# 3590/4405
# 3600/4405
# 3610/4405
# 3620/4405
# 3630/4405
# 3640/4405
# 3650/4405
# 3660/4405
# 3670/4405
# 3680/4405
# 3690/4405
# 3700/4405
# 3710/4405
# 3720/4405
# 3730/4405
# 3740/4405
# 3750/4405
# 3760/4405
# 3770/4405
# 3780/4405
# 3790/4405
# 3800/4405
# 3810/4405
# 3820/4405
# 3830/4405
# 3840/4405
# 3850/4405
# 3860/4405
# 3870/4405
# 3880/4405
# 3890/4405
# 3900/4405
# 3910/4405
# 3920/4405
# 3930/4405
# 3940/4405
# 3950/4405
# 3960/4405
# 3970/4405
# 3980/4405
# 3990/4405
# 4000/4405
# 4010/4405
# 4020/4405
# 4030/4405
# 4040/4405
# 4050/4405
# 4060/4405
# 4070/4405
# 4080/4405
# 4090/4405
# 4100/4405
# 4110/4405
# 4120/4405
# 4130/4405
# 4140/4405
# 4150/4405
# 4160/4405
# 4170/4405
# 4180/4405
# 4190/4405
# 4200/4405
# 4210/4405
# 4220/4405
# 4230/4405
# 4240/4405
# 4250/4405
# 4260/4405
# 4270/4405
# 4280/4405
# 4290/4405
# 4300/4405
# 4310/4405
# 4320/4405
# 4330/4405
# 4340/4405
# 4350/4405
# 4360/4405
# 4370/4405
# 4380/4405
# 4390/4405
# 4400/4405

# %%
record.rename(columns={"RaceID":"race_id"}, inplace=True)
record.to_csv("total_3.csv")
