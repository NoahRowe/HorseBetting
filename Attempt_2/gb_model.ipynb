# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingClassifier

from helper import *

import pandas as pd
import numpy as np

training = pd.read_csv('training.csv')
testing = pd.read_csv('testing.csv')
feats = ['actual_weight','declared_horse_weight','draw','win_odds','jockey_ave_rank','trainer_ave_rank',
'recent_ave_rank','race_distance']
targs = ['HorseWin','HorseRankTop3','HorseRankTop50Percent']
X_train = training[feats]
y_train = training[targs]
X_test = testing[feats]
y_test = testing[targs]

kfold = KFold(n_splits = 5)

# %%
gb_model = GradientBoostingClassifier()
crossVal(training, feats, 'HorseRankTop50Percent', gb_model)
crossVal(training, feats, 'HorseRankTop3', gb_model)
crossVal(training, feats, 'HorseWin', gb_model)
# Out:
# Mean score: 0.710 +/- 0.004
# [0.7150121065375307, 0.7059624697336564, 0.7052461662631162, 0.7132089778586603]
# Mean score: 0.555 +/- 0.015
# [0.5522598870056498, 0.5353107344632768, 0.5572033898305084, 0.5767869780608634]
# Mean score: 0.377 +/- 0.018
# [0.4004237288135593, 0.3665254237288136, 0.3538135593220339, 0.3885350318471338]
# (0.3773244359278851, 0.018225221369945626)

# %%
gb_model.fit(X_train, y_train["HorseWin"])
testGroups = [len(testing.loc[testing["race_id"]==race_id]) for race_id in np.unique(testing["race_id"])]
winnerEval(gb_model, X_test, y_test["HorseWin"], "HorseWin", testGroups)
# Out:
# 0.35

# %%
for i in range(len(y_test)):
    print(testing["race_id"].iloc[i],preds[i][1], y_test["HorseWin"].iloc[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-44dbe289da28> in <module>
#       1 for i in range(len(y_test)):
# ----> 2     print(testing["race_id"].iloc[i],preds[i][1], y_test["HorseWin"].iloc[i])
#
# NameError: name 'preds' is not defined
