# %%
from feature_functions import *
# USES THE MAIN TO ADD FEATURES

# %%
# Add more columns
# addLastRaceResult()
# runs.to_pickle("Data/main_1.df")
# addWinPercent()
# runs.to_pickle("Data/main_1.df")
#addTimeForDistanceAndNormalized()
# runs.to_pickle("Data/main_1.df")
# addGoingType()
# runs.to_pickle("Data/main_1.df")
# addGoingTypeRecord()
# runs.to_pickle("Data/main_1.df")
# addScaledWeights()
# runs.to_pickle("Data/main_1.df")
# fillPlaceOdds()
# runs.to_pickle("Data/main_1.df")
# addHorseRaces()
# runs.to_pickle("Data/main_1.df")
# oneHotEncodeRunVal("horse_type")
# runs.to_pickle("Data/main_1.df")
# oneHotEncodeRunVal("horse_country")
# runs.to_pickle("Data/main_1.df")
# oneHotEncodeRunVal("going_type")
# runs.to_pickle("Data/main_1.df")
# fillPlaceOdds()
# runs.to_pickle("Data/main_1.df")
# addJockeyRecord()
# runs.to_pickle("Data/main_1.df")
# addTrainerRecord()
# runs.to_pickle("Data/main_1.df")
# addHorseRecord()
# runs.to_pickle("Data/main_1.df")
# addDaysSinceLastRun()
# runs.to_pickle("Data/main_1.df")
#addWeightChange()
#runs.to_pickle("Data/main_1.df")
#addNormalizedResult()
#runs.to_pickle("Data/main_1.df")
#addVenueStats()
#runs.to_pickle("Data/main_1.df")
#addRaceStats()
#runs.to_pickle("Data/main_1.df")
#addNewHorse()
#runs.to_pickle("Data/main_1.df")
addStartSpeed()
runs.to_pickle("Data/main_1.df")
addSurfaceRecord()
runs.to_pickle("Data/main_1.df")
# Out:
# 0/79447 (0.000%)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-153c90fbe75c> in <module>
#      42 #addNewHorse()
#      43 #runs.to_pickle("Data/main_1.df")
# ---> 44 addStartSpeed()
#      45 runs.to_pickle("Data/main_1.df")
#      46 addSurfaceRecord()
#
# ~/Kaggle/HorseRacing/feature_functions.py in addStartSpeed()
#     566             speed[i] = avgSpeed
#     567         else:
# --> 568             speed[i] = horse_prev_races["time_1"].mean()
#     569
#     570         printProgress(i)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_1'

# %%
for col in runs.columns:
    print(col)

# %%
runs.head(20)

# %%
runs.columns[runs.isnull().any()]

# %%
runs[""]
