# %%
# FOR TUNING PARAMS
# https://www.youtube.com/watch?v=dMulLZKm_pg

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import xgboost as xgb
from xgboost import DMatrix

import itertools

runs = pd.read_pickle("Data/main_1.df")
runs = runs.iloc[int(len(runs)*.1):,:]
num_races = len(np.unique(runs["race_id"]))
TARGET = "result"
FEATURES = ["horse_no", "horse_age", "horse_rating", "declared_weight", "actual_weight", 
            "win_odds", "draw", #"race_size", "distance", "race_class", 
            'last_race_result','win_percent', 
            'avg_distance_time', 'normal_avg_distance_time',
            'going_type_record', 'actual_weight_scaled',
            'declared_weight_scaled', 'horse_race_count', "jockey_record",
            'trainer_record', 'horse_record', 'surface_record', 'place_odds',
            'weight_change', 'weight_change_over_time','weight_change_from_average', 'weight_change_increase',
            'venue_change','venue_record', 'days_since_last_race', 'new_horse',
            'best_odds', 'best_win_percent', 'best_distance_time', 'best_going_record', 
            'best_horse_record', 'best_jockey_record','best_trainer_record', 'highest_actual_weight', 
            'lowest_actual_weight', 'start_speed', 'rode_before']

X = runs[FEATURES]
y = runs[TARGET]

testPct = 0.2
trainIndex = int(num_races * (1-testPct))
max_race_id = np.unique(runs["race_id"])[trainIndex]
X_train = X.loc[runs["race_id"]<=max_race_id]
y_train = y.loc[runs["race_id"]<=max_race_id]
X_test = X.loc[runs["race_id"]>max_race_id]
y_test = y.loc[runs["race_id"]>max_race_id]

groups_train = [len(runs.loc[runs["race_id"]==race_id]["race_id"]) for race_id in np.unique(runs.loc[runs["race_id"]<=max_race_id]["race_id"])]
groups_test = [len(runs.loc[runs["race_id"]==race_id]["race_id"]) for race_id in np.unique(runs.loc[runs["race_id"]>max_race_id]["race_id"])]

#n_samples = len(FEATURES) 
#n_groups = len(groups)

# %%
train_dmatrix = DMatrix(X_train, label=y_train)

valid_dmatrix = DMatrix(X_test, label=y_test)

train_dmatrix.set_group(groups_train)
valid_dmatrix.set_group(groups_test)

params = {'objective': 'rank:pairwise', 'eta': .2, 'gamma': 1,
          'min_child_weight': 0.1, 'eval_metric':'ndcg',
          'seed':1212}
xgb_model = xgb.train(params, train_dmatrix, num_boost_round=500,
                      evals=[(valid_dmatrix, 'validation')]
                     )
# Out:
# [0]	validation-ndcg:0.71390
# [1]	validation-ndcg:0.71210
# [2]	validation-ndcg:0.71664
# [3]	validation-ndcg:0.71725
# [4]	validation-ndcg:0.71951
# [5]	validation-ndcg:0.71987
# [6]	validation-ndcg:0.71986
# [7]	validation-ndcg:0.71965
# [8]	validation-ndcg:0.72084
# [9]	validation-ndcg:0.72116
# [10]	validation-ndcg:0.72227
# [11]	validation-ndcg:0.72016
# [12]	validation-ndcg:0.72174
# [13]	validation-ndcg:0.72109
# [14]	validation-ndcg:0.72093
# [15]	validation-ndcg:0.72195
# [16]	validation-ndcg:0.71875
# [17]	validation-ndcg:0.71868
# [18]	validation-ndcg:0.71798
# [19]	validation-ndcg:0.71892
# [20]	validation-ndcg:0.71919
# [21]	validation-ndcg:0.71923
# [22]	validation-ndcg:0.71963
# [23]	validation-ndcg:0.71927
# [24]	validation-ndcg:0.71935
# [25]	validation-ndcg:0.71925
# [26]	validation-ndcg:0.71830
# [27]	validation-ndcg:0.71915
# [28]	validation-ndcg:0.71843
# [29]	validation-ndcg:0.71883
# [30]	validation-ndcg:0.71806
# [31]	validation-ndcg:0.71657
# [32]	validation-ndcg:0.71708
# [33]	validation-ndcg:0.71755
# [34]	validation-ndcg:0.71674
# [35]	validation-ndcg:0.71754
# [36]	validation-ndcg:0.71678
# [37]	validation-ndcg:0.71737
# [38]	validation-ndcg:0.71681
# [39]	validation-ndcg:0.71639
# [40]	validation-ndcg:0.71639
# [41]	validation-ndcg:0.71670
# [42]	validation-ndcg:0.71644
# [43]	validation-ndcg:0.71633
# [44]	validation-ndcg:0.71623
# [45]	validation-ndcg:0.71589
# [46]	validation-ndcg:0.71600
# [47]	validation-ndcg:0.71572
# [48]	validation-ndcg:0.71620
# [49]	validation-ndcg:0.71626
# [50]	validation-ndcg:0.71550
# [51]	validation-ndcg:0.71525
# [52]	validation-ndcg:0.71587
# [53]	validation-ndcg:0.71599
# [54]	validation-ndcg:0.71628
# [55]	validation-ndcg:0.71479
# [56]	validation-ndcg:0.71434
# [57]	validation-ndcg:0.71477
# [58]	validation-ndcg:0.71533
# [59]	validation-ndcg:0.71570
# [60]	validation-ndcg:0.71552
# [61]	validation-ndcg:0.71543
# [62]	validation-ndcg:0.71620
# [63]	validation-ndcg:0.71582
# [64]	validation-ndcg:0.71477
# [65]	validation-ndcg:0.71479
# [66]	validation-ndcg:0.71483
# [67]	validation-ndcg:0.71469
# [68]	validation-ndcg:0.71499
# [69]	validation-ndcg:0.71393
# [70]	validation-ndcg:0.71399
# [71]	validation-ndcg:0.71383
# [72]	validation-ndcg:0.71444
# [73]	validation-ndcg:0.71422
# [74]	validation-ndcg:0.71422
# [75]	validation-ndcg:0.71365
# [76]	validation-ndcg:0.71525
# [77]	validation-ndcg:0.71575
# [78]	validation-ndcg:0.71565
# [79]	validation-ndcg:0.71500
# [80]	validation-ndcg:0.71452
# [81]	validation-ndcg:0.71421
# [82]	validation-ndcg:0.71455
# [83]	validation-ndcg:0.71454
# [84]	validation-ndcg:0.71407
# [85]	validation-ndcg:0.71465
# [86]	validation-ndcg:0.71487
# [87]	validation-ndcg:0.71557
# [88]	validation-ndcg:0.71569
# [89]	validation-ndcg:0.71563
# [90]	validation-ndcg:0.71608
# [91]	validation-ndcg:0.71571
# [92]	validation-ndcg:0.71564
# [93]	validation-ndcg:0.71542
# [94]	validation-ndcg:0.71565
# [95]	validation-ndcg:0.71630
# [96]	validation-ndcg:0.71614
# [97]	validation-ndcg:0.71602
# [98]	validation-ndcg:0.71651
# [99]	validation-ndcg:0.71567
# [100]	validation-ndcg:0.71572
# [101]	validation-ndcg:0.71518
# [102]	validation-ndcg:0.71563
# [103]	validation-ndcg:0.71540
# [104]	validation-ndcg:0.71540
# [105]	validation-ndcg:0.71482
# [106]	validation-ndcg:0.71482
# [107]	validation-ndcg:0.71555
# [108]	validation-ndcg:0.71553
# [109]	validation-ndcg:0.71532
# [110]	validation-ndcg:0.71606
# [111]	validation-ndcg:0.71579
# [112]	validation-ndcg:0.71583
# [113]	validation-ndcg:0.71607
# [114]	validation-ndcg:0.71618
# [115]	validation-ndcg:0.71643
# [116]	validation-ndcg:0.71634
# [117]	validation-ndcg:0.71652
# [118]	validation-ndcg:0.71632
# [119]	validation-ndcg:0.71571
# [120]	validation-ndcg:0.71549
# [121]	validation-ndcg:0.71520
# [122]	validation-ndcg:0.71497
# [123]	validation-ndcg:0.71511
# [124]	validation-ndcg:0.71419
# [125]	validation-ndcg:0.71435
# [126]	validation-ndcg:0.71496
# [127]	validation-ndcg:0.71449
# [128]	validation-ndcg:0.71439
# [129]	validation-ndcg:0.71410
# [130]	validation-ndcg:0.71440
# [131]	validation-ndcg:0.71413
# [132]	validation-ndcg:0.71428
# [133]	validation-ndcg:0.71431
# [134]	validation-ndcg:0.71305
# [135]	validation-ndcg:0.71381
# [136]	validation-ndcg:0.71358
# [137]	validation-ndcg:0.71359
# [138]	validation-ndcg:0.71389
# [139]	validation-ndcg:0.71364
# [140]	validation-ndcg:0.71332
# [141]	validation-ndcg:0.71325
# [142]	validation-ndcg:0.71345
# [143]	validation-ndcg:0.71333
# [144]	validation-ndcg:0.71386
# [145]	validation-ndcg:0.71469
# [146]	validation-ndcg:0.71506
# [147]	validation-ndcg:0.71530
# [148]	validation-ndcg:0.71423
# [149]	validation-ndcg:0.71411
# [150]	validation-ndcg:0.71387
# [151]	validation-ndcg:0.71405
# [152]	validation-ndcg:0.71354
# [153]	validation-ndcg:0.71317
# [154]	validation-ndcg:0.71349
# [155]	validation-ndcg:0.71338
# [156]	validation-ndcg:0.71386
# [157]	validation-ndcg:0.71322
# [158]	validation-ndcg:0.71318
# [159]	validation-ndcg:0.71325
# [160]	validation-ndcg:0.71420
# [161]	validation-ndcg:0.71372
# [162]	validation-ndcg:0.71405
# [163]	validation-ndcg:0.71438
# [164]	validation-ndcg:0.71439
# [165]	validation-ndcg:0.71425
# [166]	validation-ndcg:0.71389
# [167]	validation-ndcg:0.71372
# [168]	validation-ndcg:0.71409
# [169]	validation-ndcg:0.71251
# [170]	validation-ndcg:0.71261
# [171]	validation-ndcg:0.71293
# [172]	validation-ndcg:0.71336
# [173]	validation-ndcg:0.71346
# [174]	validation-ndcg:0.71293
# [175]	validation-ndcg:0.71257
# [176]	validation-ndcg:0.71235
# [177]	validation-ndcg:0.71191
# [178]	validation-ndcg:0.71193
# [179]	validation-ndcg:0.71209
# [180]	validation-ndcg:0.71234
# [181]	validation-ndcg:0.71259
# [182]	validation-ndcg:0.71212
# [183]	validation-ndcg:0.71231
# [184]	validation-ndcg:0.71149
# [185]	validation-ndcg:0.71129
# [186]	validation-ndcg:0.71137
# [187]	validation-ndcg:0.71122
# [188]	validation-ndcg:0.71079
# [189]	validation-ndcg:0.71048
# [190]	validation-ndcg:0.71144
# [191]	validation-ndcg:0.71119
# [192]	validation-ndcg:0.71149
# [193]	validation-ndcg:0.71147
# [194]	validation-ndcg:0.71169
# [195]	validation-ndcg:0.71088
# [196]	validation-ndcg:0.71157
# [197]	validation-ndcg:0.71152
# [198]	validation-ndcg:0.71135
# [199]	validation-ndcg:0.71121
# [200]	validation-ndcg:0.71122
# [201]	validation-ndcg:0.71126
# [202]	validation-ndcg:0.71114
# [203]	validation-ndcg:0.71083
# [204]	validation-ndcg:0.71041
# [205]	validation-ndcg:0.71023
# [206]	validation-ndcg:0.71005
# [207]	validation-ndcg:0.71025
# [208]	validation-ndcg:0.71096
# [209]	validation-ndcg:0.71030
# [210]	validation-ndcg:0.71093
# [211]	validation-ndcg:0.71059
# [212]	validation-ndcg:0.71037
# [213]	validation-ndcg:0.71124
# [214]	validation-ndcg:0.71118
# [215]	validation-ndcg:0.71102
# [216]	validation-ndcg:0.71125
# [217]	validation-ndcg:0.71096
# [218]	validation-ndcg:0.71116
# [219]	validation-ndcg:0.71134
# [220]	validation-ndcg:0.71092
# [221]	validation-ndcg:0.71096
# [222]	validation-ndcg:0.71121
# [223]	validation-ndcg:0.71133
# [224]	validation-ndcg:0.71101
# [225]	validation-ndcg:0.71109
# [226]	validation-ndcg:0.71157
# [227]	validation-ndcg:0.71125
# [228]	validation-ndcg:0.71123
# [229]	validation-ndcg:0.71079
# [230]	validation-ndcg:0.71007
# [231]	validation-ndcg:0.71052
# [232]	validation-ndcg:0.71096
# [233]	validation-ndcg:0.71070
# [234]	validation-ndcg:0.71201
# [235]	validation-ndcg:0.71215
# [236]	validation-ndcg:0.71204
# [237]	validation-ndcg:0.71212
# [238]	validation-ndcg:0.71169
# [239]	validation-ndcg:0.71169
# [240]	validation-ndcg:0.71178
# [241]	validation-ndcg:0.71157
# [242]	validation-ndcg:0.71189
# [243]	validation-ndcg:0.71206
# [244]	validation-ndcg:0.71127
# [245]	validation-ndcg:0.71049
# [246]	validation-ndcg:0.71031
# [247]	validation-ndcg:0.71074
# [248]	validation-ndcg:0.71040
# [249]	validation-ndcg:0.71061
# [250]	validation-ndcg:0.71123
# [251]	validation-ndcg:0.71109
# [252]	validation-ndcg:0.71140
# [253]	validation-ndcg:0.71115
# [254]	validation-ndcg:0.71131
# [255]	validation-ndcg:0.71080
# [256]	validation-ndcg:0.71039
# [257]	validation-ndcg:0.71070
# [258]	validation-ndcg:0.71022
# [259]	validation-ndcg:0.71044
# [260]	validation-ndcg:0.71116
# [261]	validation-ndcg:0.71076
# [262]	validation-ndcg:0.70940
# [263]	validation-ndcg:0.70948
# [264]	validation-ndcg:0.70943
# [265]	validation-ndcg:0.70880
# [266]	validation-ndcg:0.70803
# [267]	validation-ndcg:0.70841
# [268]	validation-ndcg:0.70799
# [269]	validation-ndcg:0.70792
# [270]	validation-ndcg:0.70797
# [271]	validation-ndcg:0.70845
# [272]	validation-ndcg:0.70896
# [273]	validation-ndcg:0.70919
# [274]	validation-ndcg:0.70884
# [275]	validation-ndcg:0.70886
# [276]	validation-ndcg:0.70766
# [277]	validation-ndcg:0.70793
# [278]	validation-ndcg:0.70827
# [279]	validation-ndcg:0.70819
# [280]	validation-ndcg:0.70885
# [281]	validation-ndcg:0.70795
# [282]	validation-ndcg:0.70833
# [283]	validation-ndcg:0.70783
# [284]	validation-ndcg:0.70764
# [285]	validation-ndcg:0.70900
# [286]	validation-ndcg:0.70906
# [287]	validation-ndcg:0.70913
# [288]	validation-ndcg:0.70897
# [289]	validation-ndcg:0.70889
# [290]	validation-ndcg:0.70847
# [291]	validation-ndcg:0.70849
# [292]	validation-ndcg:0.70836
# [293]	validation-ndcg:0.70879
# [294]	validation-ndcg:0.70890
# [295]	validation-ndcg:0.70845
# [296]	validation-ndcg:0.70871
# [297]	validation-ndcg:0.70804
# [298]	validation-ndcg:0.70773
# [299]	validation-ndcg:0.70796
# [300]	validation-ndcg:0.70787
# [301]	validation-ndcg:0.70789
# [302]	validation-ndcg:0.70786
# [303]	validation-ndcg:0.70803
# [304]	validation-ndcg:0.70753
# [305]	validation-ndcg:0.70753
# [306]	validation-ndcg:0.70769
# [307]	validation-ndcg:0.70742
# [308]	validation-ndcg:0.70808
# [309]	validation-ndcg:0.70799
# [310]	validation-ndcg:0.70844
# [311]	validation-ndcg:0.70822
# [312]	validation-ndcg:0.70812
# [313]	validation-ndcg:0.70801
# [314]	validation-ndcg:0.70795
# [315]	validation-ndcg:0.70800
# [316]	validation-ndcg:0.70852
# [317]	validation-ndcg:0.70833
# [318]	validation-ndcg:0.70802
# [319]	validation-ndcg:0.70820
# [320]	validation-ndcg:0.70823
# [321]	validation-ndcg:0.70865
# [322]	validation-ndcg:0.70884
# [323]	validation-ndcg:0.70941
# [324]	validation-ndcg:0.70915
# [325]	validation-ndcg:0.70903
# [326]	validation-ndcg:0.70927
# [327]	validation-ndcg:0.70905
# [328]	validation-ndcg:0.70912
# [329]	validation-ndcg:0.70916
# [330]	validation-ndcg:0.70920
# [331]	validation-ndcg:0.70858
# [332]	validation-ndcg:0.70870
# [333]	validation-ndcg:0.70849
# [334]	validation-ndcg:0.70819
# [335]	validation-ndcg:0.70796
# [336]	validation-ndcg:0.70798
# [337]	validation-ndcg:0.70797
# [338]	validation-ndcg:0.70772
# [339]	validation-ndcg:0.70814
# [340]	validation-ndcg:0.70796
# [341]	validation-ndcg:0.70770
# [342]	validation-ndcg:0.70735
# [343]	validation-ndcg:0.70753
# [344]	validation-ndcg:0.70717
# [345]	validation-ndcg:0.70675
# [346]	validation-ndcg:0.70703
# [347]	validation-ndcg:0.70684
# [348]	validation-ndcg:0.70706
# [349]	validation-ndcg:0.70725
# [350]	validation-ndcg:0.70706
# [351]	validation-ndcg:0.70704
# [352]	validation-ndcg:0.70646
# [353]	validation-ndcg:0.70734
# [354]	validation-ndcg:0.70714
# [355]	validation-ndcg:0.70693
# [356]	validation-ndcg:0.70733
# [357]	validation-ndcg:0.70712
# [358]	validation-ndcg:0.70666
# [359]	validation-ndcg:0.70630
# [360]	validation-ndcg:0.70664
# [361]	validation-ndcg:0.70682
# [362]	validation-ndcg:0.70703
# [363]	validation-ndcg:0.70708
# [364]	validation-ndcg:0.70669
# [365]	validation-ndcg:0.70673
# [366]	validation-ndcg:0.70668
# [367]	validation-ndcg:0.70674
# [368]	validation-ndcg:0.70657
# [369]	validation-ndcg:0.70703
# [370]	validation-ndcg:0.70683
# [371]	validation-ndcg:0.70682
# [372]	validation-ndcg:0.70725
# [373]	validation-ndcg:0.70730
# [374]	validation-ndcg:0.70654
# [375]	validation-ndcg:0.70636
# [376]	validation-ndcg:0.70651
# [377]	validation-ndcg:0.70637
# [378]	validation-ndcg:0.70625
# [379]	validation-ndcg:0.70656
# [380]	validation-ndcg:0.70668
# [381]	validation-ndcg:0.70664
# [382]	validation-ndcg:0.70620
# [383]	validation-ndcg:0.70615
# [384]	validation-ndcg:0.70619
# [385]	validation-ndcg:0.70647
# [386]	validation-ndcg:0.70674
# [387]	validation-ndcg:0.70665
# [388]	validation-ndcg:0.70701
# [389]	validation-ndcg:0.70663
# [390]	validation-ndcg:0.70678
# [391]	validation-ndcg:0.70696
# [392]	validation-ndcg:0.70676
# [393]	validation-ndcg:0.70657
# [394]	validation-ndcg:0.70639
# [395]	validation-ndcg:0.70696
# [396]	validation-ndcg:0.70661
# [397]	validation-ndcg:0.70694
# [398]	validation-ndcg:0.70628
# [399]	validation-ndcg:0.70650
# [400]	validation-ndcg:0.70612
# [401]	validation-ndcg:0.70556
# [402]	validation-ndcg:0.70568
# [403]	validation-ndcg:0.70567
# [404]	validation-ndcg:0.70572
# [405]	validation-ndcg:0.70589
# [406]	validation-ndcg:0.70652
# [407]	validation-ndcg:0.70635
# [408]	validation-ndcg:0.70584
# [409]	validation-ndcg:0.70607
# [410]	validation-ndcg:0.70651
# [411]	validation-ndcg:0.70610
# [412]	validation-ndcg:0.70570
# [413]	validation-ndcg:0.70546
# [414]	validation-ndcg:0.70568
# [415]	validation-ndcg:0.70608
# [416]	validation-ndcg:0.70569
# [417]	validation-ndcg:0.70533
# [418]	validation-ndcg:0.70524
# [419]	validation-ndcg:0.70515
# [420]	validation-ndcg:0.70522
# [421]	validation-ndcg:0.70489
# [422]	validation-ndcg:0.70485
# [423]	validation-ndcg:0.70496
# [424]	validation-ndcg:0.70499
# [425]	validation-ndcg:0.70513
# [426]	validation-ndcg:0.70502
# [427]	validation-ndcg:0.70488
# [428]	validation-ndcg:0.70401
# [429]	validation-ndcg:0.70340
# [430]	validation-ndcg:0.70373
# [431]	validation-ndcg:0.70368
# [432]	validation-ndcg:0.70371
# [433]	validation-ndcg:0.70375
# [434]	validation-ndcg:0.70344
# [435]	validation-ndcg:0.70307
# [436]	validation-ndcg:0.70296
# [437]	validation-ndcg:0.70253
# [438]	validation-ndcg:0.70289
# [439]	validation-ndcg:0.70322
# [440]	validation-ndcg:0.70309
# [441]	validation-ndcg:0.70281
# [442]	validation-ndcg:0.70271
# [443]	validation-ndcg:0.70331
# [444]	validation-ndcg:0.70340
# [445]	validation-ndcg:0.70318
# [446]	validation-ndcg:0.70303
# [447]	validation-ndcg:0.70275
# [448]	validation-ndcg:0.70293
# [449]	validation-ndcg:0.70295
# [450]	validation-ndcg:0.70297
# [451]	validation-ndcg:0.70320
# [452]	validation-ndcg:0.70329
# [453]	validation-ndcg:0.70335
# [454]	validation-ndcg:0.70236
# [455]	validation-ndcg:0.70268
# [456]	validation-ndcg:0.70288
# [457]	validation-ndcg:0.70386
# [458]	validation-ndcg:0.70387
# [459]	validation-ndcg:0.70378
# [460]	validation-ndcg:0.70347
# [461]	validation-ndcg:0.70414
# [462]	validation-ndcg:0.70428
# [463]	validation-ndcg:0.70434
# [464]	validation-ndcg:0.70400
# [465]	validation-ndcg:0.70438
# [466]	validation-ndcg:0.70405
# [467]	validation-ndcg:0.70345
# [468]	validation-ndcg:0.70374
# [469]	validation-ndcg:0.70341
# [470]	validation-ndcg:0.70312
# [471]	validation-ndcg:0.70268
# [472]	validation-ndcg:0.70298
# [473]	validation-ndcg:0.70257
# [474]	validation-ndcg:0.70289
# [475]	validation-ndcg:0.70299
# [476]	validation-ndcg:0.70270
# [477]	validation-ndcg:0.70256
# [478]	validation-ndcg:0.70302
# [479]	validation-ndcg:0.70243
# [480]	validation-ndcg:0.70259
# [481]	validation-ndcg:0.70273
# [482]	validation-ndcg:0.70358
# [483]	validation-ndcg:0.70309
# [484]	validation-ndcg:0.70268
# [485]	validation-ndcg:0.70284
# [486]	validation-ndcg:0.70298
# [487]	validation-ndcg:0.70277
# [488]	validation-ndcg:0.70216
# [489]	validation-ndcg:0.70167
# [490]	validation-ndcg:0.70226
# [491]	validation-ndcg:0.70211
# [492]	validation-ndcg:0.70166
# [493]	validation-ndcg:0.70199
# [494]	validation-ndcg:0.70238
# [495]	validation-ndcg:0.70194
# [496]	validation-ndcg:0.70185
# [497]	validation-ndcg:0.70227
# [498]	validation-ndcg:0.70125
# [499]	validation-ndcg:0.70135

# %%
def RankEval(xgb_model, x_test, y_test, groups_test):
    pred = xgb_model.predict(DMatrix(x_test))
    s = 0
    wCount = 0
    for i, groupNum in enumerate(groups_test):
        realVals = y_train[s:s+groupNum].to_list()
        predVals = pred[s:s+groupNum]
        
        output = [0] * groupNum
        for j, x in enumerate(sorted(range(len(predVals)), key=lambda y: predVals[y])):
            output[x] = j+1
        s += groupNum

        if realVals[0]==output[0]:
            wCount += 1
            
    return wCount/float(len(groups_test))

# %%
print(RankEval(xgb_model, X_test, y_test, groups_test))
# Out:
# 0.08238387379491674
