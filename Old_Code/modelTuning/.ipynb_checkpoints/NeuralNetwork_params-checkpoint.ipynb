# %%
import sys
sys.path.append('../')
from helper import *

from sklearn.neural_network import MLPClassifier

import matplotlib.pyplot as plt

runs = pd.read_pickle("../Data/main_1.df")

FEATURES = ["horse_no", "horse_age", "horse_rating", "declared_weight", "actual_weight", 
            "win_odds", "draw", "race_size", "distance", "race_class", 
            'last_race_result','win_percent', 
            'avg_distance_time', 'normal_avg_distance_time',
            'going_type_record', 'actual_weight_scaled',
            'declared_weight_scaled', 'horse_race_count', "jockey_record",
            'trainer_record', 'horse_record', 'surface_record', 'place_odds',
            'weight_change', 'weight_change_over_time','weight_change_from_average', 'weight_change_increase',
            'venue_change','venue_record', 'days_since_last_race', 'new_horse',
            'best_odds', 'best_win_percent', 'best_distance_time', 'best_going_record', 
            'best_horse_record', 'best_jockey_record','best_trainer_record', 'highest_actual_weight', 
            'lowest_actual_weight', 'start_speed', 'rode_before',
           'horse_type_Brown',
           'horse_type_Colt', 'horse_type_Filly', 'horse_type_Gelding',
           'horse_type_Grey', 'horse_type_Horse', 'horse_type_Mare',
           'horse_type_Rig', 'horse_type_Roan', 'horse_country_ARG',
           'horse_country_AUS', 'horse_country_BRZ', 'horse_country_CAN',
           'horse_country_FR', 'horse_country_GB', 'horse_country_GER',
           'horse_country_GR', 'horse_country_IRE', 'horse_country_ITY',
           'horse_country_JPN', 'horse_country_NZ', 'horse_country_SAF',
           'horse_country_SPA', 'horse_country_USA', 'horse_country_ZIM',
          'going_type_fast', 'going_type_slow', 'going_type_wet'
           ]
TARGET = "won"

# %%
# THINGS TO FIGURE OUT:
# Hidden layers
# activation
# solver
# alpha
# learning rate

# %%
# Baseline
bl_model = MLPClassifier(solver='adam', hidden_layer_sizes=(int(len(FEATURES)/2)))
bl_meanScore, bl_stdScore = crossVal(runs, FEATURES, TARGET, bl_model)
# Out:
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.008

# %%
# Find best solver - adam
solvers = ["adam", "lbfgs", "sgd"]

for solver in solvers:
    
    model = MLPClassifier(
        solver=solver,
        hidden_layer_sizes=(int(len(FEATURES)/2))
    )
    
    print("solver: {}".format(solver))
    meanScore, stdScore = crossVal(runs, FEATURES, TARGET, model)
# Out:
# solver: adam
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.296 +/- 0.010
# solver: lbfgs
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.126 +/- 0.065
# solver: sgd
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.242 +/- 0.079

# %%
# Find best activation - Identity
activations = ['identity', 'logistic', 'tanh', 'relu']

for act in activations:
    
    model = MLPClassifier(
        solver="adam",
        activation=act,
        hidden_layer_sizes=(int(len(FEATURES)/2))
    )
    
    print("Activation: {}".format(act))
    meanScore, stdScore = crossVal(runs, FEATURES, TARGET, model)
# Out:
# Activation: identity
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.005
# Activation: logistic
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.257 +/- 0.066
# Activation: tanh
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.282 +/- 0.018
# Activation: relu
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.296 +/- 0.011

# %%
# Find best hidden layers FOR ONE LAYER ....... (int(len(FEATURES)/2))
layers = [None,(len(FEATURES)), (int(len(FEATURES)/2)), (int(len(FEATURES)/3)), (int(len(FEATURES)/4))]

for lay in layers:
    if lay==None:
        model = MLPClassifier(
        solver="adam",
        activation="identity"
    )
    else: 
        model = MLPClassifier(
            solver="adam",
            activation="identity",
            hidden_layer_sizes=lay
        )
    
    print("Layer: {}".format(lay))
    meanScore, stdScore = crossVal(runs, FEATURES, TARGET, model)
# Out:
# Layer: None
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.296 +/- 0.007
# Layer: 70
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.296 +/- 0.008
# Layer: 35
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.006
# Layer: 23
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.009
# Layer: 17
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.013
# Layer: 35
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.296 +/- 0.007

# %%
# Find best hidden layers FOR TWO LAYER .......
layers = [(int(len(FEATURES)/2), int(len(FEATURES))), (int(len(FEATURES)/2), int(len(FEATURES)/2)),
         (int(len(FEATURES)/2), int(len(FEATURES)/3)), (int(len(FEATURES)/2), int(len(FEATURES)/4)),
         (int(len(FEATURES)/2), int(len(FEATURES)/5)), (int(len(FEATURES)/2), int(len(FEATURES)/6)),]

for lay in layers:

    model = MLPClassifier(
        solver="adam",
        activation="identity",
        hidden_layer_sizes=lay
    )
    
    print("Layer: {}".format(lay))
    meanScore, stdScore = crossVal(runs, FEATURES, TARGET, model)
# Out:
# Layer: (35, 70)
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.296 +/- 0.013
# Layer: (35, 35)
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.011
# Layer: (35, 23)
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.010
# Layer: (35, 17)
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.296 +/- 0.011
# Layer: (35, 14)
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.004
# Layer: (35, 11)
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.296 +/- 0.006

# %%
# Conclude that the best way to go is FEAT/2 one layer

# %%
# alpha value
alphas = [0.05, 0.03, 0.01, 0.009, 0.002]
for a in alphas:
    model = MLPClassifier(
        solver="adam",
        activation="identity",
        hidden_layer_sizes=(int(len(FEATURES)/2)),
        alpha=a
    )
    print("Alpha: {}".format(a))
    meanScore, stdScore = crossVal(runs, FEATURES, TARGET, model)
# Out:
# Alpha: 0.05
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.006
# Alpha: 0.03
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.296 +/- 0.013
# Alpha: 0.01
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.007
# Alpha: 0.009
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.008
# Alpha: 0.002
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.010

# %%
# Learning rate
vals = ["constant", "invscaling", "adaptive"]
for val in vals:
    model = MLPClassifier(
        solver="adam",
        activation="identity",
        hidden_layer_sizes=(int(len(FEATURES)/2)),
        alpha=0.002, 
        learning_rate=val
    )
    print("Learning Rate: {}".format(val))
    meanScore, stdScore = crossVal(runs, FEATURES, TARGET, model)
# Out:
# Learning Rate: constant
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.298 +/- 0.015
# Learning Rate: invscaling
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.296 +/- 0.008
# Learning Rate: adaptive
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4
# Mean score: 0.297 +/- 0.009

# %%
# Learning rate init
vals = [0.01,0.02,0.03]
for val in vals:
    model = MLPClassifier(
        solver="adam",
        activation="identity",
        hidden_layer_sizes=(int(len(FEATURES)/2)),
        alpha=0.002, 
        learning_rate="constant",
        learning_rate_init=val
    )
    print("Learning Rate Init: {}".format(val))
    meanScore, stdScore = crossVal(runs, FEATURES, TARGET, model)
# Out:
# Learning Rate Init: 0.01
# CV 1/4
# CV 2/4
# CV 3/4
# CV 4/4

# %%
# Beta 1
vals = [0.2, 0.4, 0.6, 0.8, 0.9]
for val in vals:
    model = MLPClassifier(
        solver="adam",
        activation="identity",
        hidden_layer_sizes=(int(len(FEATURES)/2)),
        alpha=0.002, 
        learning_rate="constant",
        learning_rate_init=,
        beta_1=
    )
    print("Beta_1: {}".format(val))
    meanScore, stdScore = crossVal(runs, FEATURES, TARGET, model)

# %%
# Beta 2
vals = [0.2, 0.4, 0.6, 0.8, 0.9]
for val in vals:
    model = MLPClassifier(
        solver="adam",
        activation="identity",
        hidden_layer_sizes=(int(len(FEATURES)/2)),
        alpha=0.002, 
        learning_rate="constant",
        learning_rate_init=,
        beta_1=,
        beta_2=val,
    )
    print("Beta_2: {}".format(val))
    meanScore, stdScore = crossVal(runs, FEATURES, TARGET, model)

# %%
# Beta 2
vals = [0.2, 0.4, 0.6, 0.8, 0.9]
for val in vals:
    model = MLPClassifier(
        solver="adam",
        activation="identity",
        hidden_layer_sizes=(int(len(FEATURES)/2)),
        alpha=0.002, 
        learning_rate="constant",
        learning_rate_init=,
        beta_1=,
        beta_2=,
        epsilon=val,
    )
    print("epsilon: {}".format(val))
    meanScore, stdScore = crossVal(runs, FEATURES, TARGET, model)
