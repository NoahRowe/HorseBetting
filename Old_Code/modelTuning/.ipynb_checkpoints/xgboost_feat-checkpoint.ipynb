# %%
import sys
sys.path.append('../')
from helper import *

from xgboost.sklearn import XGBClassifier
import matplotlib.pyplot as plt

runs = pd.read_pickle("../Data/main_1.df")

TARGET = "won"

# define custom class to fix bug in xgboost 1.0.2
class MyXGBClassifier(XGBClassifier):
    @property
    def coef_(self):
        return None
    
thresh = bestOddsEval(runs, TARGET)
test_thresh = 0.3128447596532703

# %%
feat_1 = ["horse_no", "horse_age", "horse_rating", "declared_weight", "actual_weight", 
            "win_odds", "draw", "race_size", "distance", "race_class", 
            'last_race_result','win_percent', 
            'avg_distance_time', 'normal_avg_distance_time',
            'going_type_record', 'actual_weight_scaled',
            'declared_weight_scaled', 'horse_race_count', "jockey_record",
            'trainer_record', 'horse_record', 'surface_record', 'place_odds',
            'weight_change', 'weight_change_over_time','weight_change_from_average', 'weight_change_increase',
            'venue_change','venue_record', 'days_since_last_race', 'new_horse',
            'best_odds', 'best_win_percent', 'best_distance_time', 'best_going_record', 
            'best_horse_record', 'best_jockey_record','best_trainer_record', 'highest_actual_weight', 
            'lowest_actual_weight', 'start_speed', 'rode_before',
           'horse_type_Brown',
           'horse_type_Colt', 'horse_type_Filly', 'horse_type_Gelding',
           'horse_type_Grey', 'horse_type_Horse', 'horse_type_Mare',
           'horse_type_Rig', 'horse_type_Roan', 'horse_country_ARG',
           'horse_country_AUS', 'horse_country_BRZ', 'horse_country_CAN',
           'horse_country_FR', 'horse_country_GB', 'horse_country_GER',
           'horse_country_GR', 'horse_country_IRE', 'horse_country_ITY',
           'horse_country_JPN', 'horse_country_NZ', 'horse_country_SAF',
           'horse_country_SPA', 'horse_country_USA', 'horse_country_ZIM',
          'going_type_fast', 'going_type_slow', 'going_type_wet'
           ]
feat_2 = ["horse_no", "horse_age", "horse_rating", "declared_weight", "actual_weight", 
            "draw", "race_size", "distance", "race_class", 
            'last_race_result','win_percent', 
            'avg_distance_time', 'normal_avg_distance_time',
            'going_type_record', 'actual_weight_scaled',
            'declared_weight_scaled', 'horse_race_count', "jockey_record",
            'trainer_record', 'horse_record', 'surface_record',
            'weight_change', 'weight_change_over_time','weight_change_from_average', 'weight_change_increase',
            'venue_change','venue_record', 'days_since_last_race', 'new_horse',
            'best_win_percent', 'best_distance_time', 'best_going_record', 
            'best_horse_record', 'best_jockey_record','best_trainer_record', 'highest_actual_weight', 
            'lowest_actual_weight', 'start_speed', 'rode_before',
           'horse_type_Brown',
           'horse_type_Colt', 'horse_type_Filly', 'horse_type_Gelding',
           'horse_type_Grey', 'horse_type_Horse', 'horse_type_Mare',
           'horse_type_Rig', 'horse_type_Roan', 'horse_country_ARG',
           'horse_country_AUS', 'horse_country_BRZ', 'horse_country_CAN',
           'horse_country_FR', 'horse_country_GB', 'horse_country_GER',
           'horse_country_GR', 'horse_country_IRE', 'horse_country_ITY',
           'horse_country_JPN', 'horse_country_NZ', 'horse_country_SAF',
           'horse_country_SPA', 'horse_country_USA', 'horse_country_ZIM',
          'going_type_fast', 'going_type_slow', 'going_type_wet'
           ]

# %%
# parameter tuned model
bestModel = XGBClassifier(
    learning_rate =0.1,
    n_estimator = 750,
    booster='gblinear',
    max_depth=1,
    min_child_weight=1,
    gamma=0.0,
    subsample=0,
    colsample_bytree=0,
    reg_alpha=0.001
)
bestModel = XGBClassifier()
scores_1, feats_1 = selectFeatures_k(bestModel, runs, feat_1, TARGET)
# Out:
# k: 2/70
# k: 3/70
# k: 4/70
# k: 5/70
# k: 6/70
# k: 7/70
# k: 8/70
# k: 9/70
# k: 10/70
# k: 11/70
# k: 12/70
# k: 13/70
# k: 14/70
# k: 15/70
# k: 16/70
# k: 17/70
# k: 18/70
# k: 19/70
# k: 20/70
# k: 21/70
# k: 22/70
# k: 23/70
# k: 24/70
# k: 25/70
# k: 26/70
# k: 27/70
# k: 28/70
# k: 29/70
# k: 30/70
# k: 31/70
# k: 32/70
# k: 33/70
# k: 34/70
# k: 35/70
# k: 36/70
# k: 37/70
# k: 38/70
# k: 39/70
# k: 40/70
# k: 41/70
# k: 42/70
# k: 43/70
# k: 44/70
# k: 45/70
# k: 46/70
# k: 47/70
# k: 48/70
# k: 49/70
# k: 50/70
# k: 51/70
# k: 52/70
# k: 53/70
# k: 54/70
# k: 55/70
# k: 56/70

# %%
N_1 = len(feat_1)-1
ind_1 = np.arange(N_1)

plt.figure(figsize=(10,8), dpi=100)
plt.bar(ind_1, scores_1, label="feat_1")
#plt.bar(ind_2+offset/2., scores_2, width=offset, label="feat_2")
plt.plot([0, N_1], [thresh,thresh], "k--")
plt.plot([0, N_1], [thresh_test,thresh_test], "r--")
plt.xlabel("K value")
plt.ylabel("Score")
plt.legend()

# %%
best_feat_1 = feats_1[np.argmax(scores_1, axis=0)]

print("Best feat_1 selection:")
print(best_feat_1)
print(max(scores_1))
# Out:
# Best feat_1 selection:
# ['win_odds', 'place_odds', 'best_odds']
# 0.3128447596532703

# %%
for i in range(30):
    print(i, feats_1[i])
# Out:
# 0 ['win_odds', 'place_odds']
# 1 ['win_odds', 'place_odds', 'best_odds']
# 2 ['win_odds', 'horse_race_count', 'place_odds', 'best_odds']
# 3 ['win_odds', 'horse_race_count', 'place_odds', 'best_odds', 'best_horse_record']
# 4 ['win_odds', 'horse_race_count', 'place_odds', 'best_odds', 'best_going_record', 'best_horse_record']
# 5 ['win_odds', 'horse_race_count', 'place_odds', 'best_odds', 'best_going_record', 'best_horse_record', 'best_jockey_record']
# 6 ['win_odds', 'horse_race_count', 'place_odds', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record']
# 7 ['horse_no', 'win_odds', 'horse_race_count', 'place_odds', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record']
# 8 ['horse_no', 'win_odds', 'draw', 'horse_race_count', 'place_odds', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record']
# 9 ['horse_no', 'win_odds', 'draw', 'horse_race_count', 'place_odds', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record']
# 10 ['horse_no', 'win_odds', 'draw', 'horse_race_count', 'place_odds', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record']
# 11 ['horse_no', 'win_odds', 'draw', 'avg_distance_time', 'horse_race_count', 'place_odds', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record']
# 12 ['horse_no', 'win_odds', 'draw', 'win_percent', 'avg_distance_time', 'horse_race_count', 'place_odds', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record']
# 13 ['horse_no', 'declared_weight', 'win_odds', 'draw', 'win_percent', 'avg_distance_time', 'horse_race_count', 'place_odds', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record']
# 14 ['horse_no', 'declared_weight', 'win_odds', 'draw', 'win_percent', 'avg_distance_time', 'horse_race_count', 'place_odds', 'weight_change_from_average', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record']
# 15 ['horse_no', 'declared_weight', 'win_odds', 'draw', 'win_percent', 'avg_distance_time', 'horse_race_count', 'place_odds', 'weight_change_from_average', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight']
# 16 ['horse_no', 'declared_weight', 'win_odds', 'draw', 'win_percent', 'avg_distance_time', 'horse_race_count', 'surface_record', 'place_odds', 'weight_change_from_average', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight']
# 17 ['horse_no', 'declared_weight', 'win_odds', 'draw', 'win_percent', 'avg_distance_time', 'horse_race_count', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_record', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight']
# 18 ['horse_no', 'declared_weight', 'win_odds', 'draw', 'win_percent', 'avg_distance_time', 'horse_race_count', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_record', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight']
# 19 ['horse_no', 'declared_weight', 'win_odds', 'draw', 'win_percent', 'avg_distance_time', 'going_type_record', 'horse_race_count', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_record', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight']
# 20 ['horse_no', 'declared_weight', 'actual_weight', 'win_odds', 'draw', 'win_percent', 'avg_distance_time', 'going_type_record', 'horse_race_count', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_record', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight']
# 21 ['horse_no', 'declared_weight', 'actual_weight', 'win_odds', 'draw', 'last_race_result', 'win_percent', 'avg_distance_time', 'going_type_record', 'horse_race_count', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_record', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight']
# 22 ['horse_no', 'declared_weight', 'actual_weight', 'win_odds', 'draw', 'last_race_result', 'win_percent', 'avg_distance_time', 'going_type_record', 'horse_race_count', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_record', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight', 'rode_before']
# 23 ['horse_no', 'declared_weight', 'actual_weight', 'win_odds', 'draw', 'last_race_result', 'win_percent', 'avg_distance_time', 'going_type_record', 'horse_race_count', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_record', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight', 'lowest_actual_weight', 'rode_before']
# 24 ['horse_no', 'declared_weight', 'actual_weight', 'win_odds', 'draw', 'last_race_result', 'win_percent', 'avg_distance_time', 'going_type_record', 'horse_race_count', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_change', 'venue_record', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight', 'lowest_actual_weight', 'rode_before']
# 25 ['horse_no', 'horse_rating', 'declared_weight', 'actual_weight', 'win_odds', 'draw', 'last_race_result', 'win_percent', 'avg_distance_time', 'going_type_record', 'horse_race_count', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_change', 'venue_record', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight', 'lowest_actual_weight', 'rode_before']
# 26 ['horse_no', 'horse_rating', 'declared_weight', 'actual_weight', 'win_odds', 'draw', 'last_race_result', 'win_percent', 'avg_distance_time', 'going_type_record', 'horse_race_count', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_change', 'venue_record', 'days_since_last_race', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight', 'lowest_actual_weight', 'start_speed', 'rode_before']
# 27 ['horse_no', 'horse_rating', 'declared_weight', 'actual_weight', 'win_odds', 'draw', 'last_race_result', 'win_percent', 'avg_distance_time', 'going_type_record', 'horse_race_count', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_change', 'venue_record', 'days_since_last_race', 'new_horse', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight', 'lowest_actual_weight', 'start_speed', 'rode_before']
# 28 ['horse_no', 'horse_rating', 'declared_weight', 'actual_weight', 'win_odds', 'draw', 'race_size', 'last_race_result', 'win_percent', 'avg_distance_time', 'going_type_record', 'horse_race_count', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_change', 'venue_record', 'days_since_last_race', 'new_horse', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight', 'lowest_actual_weight', 'start_speed', 'rode_before']
# 29 ['horse_no', 'horse_rating', 'declared_weight', 'actual_weight', 'win_odds', 'draw', 'race_size', 'last_race_result', 'win_percent', 'avg_distance_time', 'going_type_record', 'horse_race_count', 'jockey_record', 'horse_record', 'surface_record', 'place_odds', 'weight_change_from_average', 'venue_change', 'venue_record', 'days_since_last_race', 'new_horse', 'best_odds', 'best_win_percent', 'best_going_record', 'best_horse_record', 'best_jockey_record', 'best_trainer_record', 'highest_actual_weight', 'lowest_actual_weight', 'start_speed', 'rode_before']

# %%
bestOddsEval(runs[int(len(runs) * 0.8):], TARGET)
# Out:
# 0.3128447596532703
