# %%
from feature_functions import *

# %%
runs
# Out:
#        race_id  horse_no  horse_id  result  won  lengths_behind  horse_age  \
# 0            0         1      3917      10    0            8.00          3
# 1            0         2      2157       8    0            5.75          3
# 2            0         3       858       7    0            4.75          3
# 3            0         4      1853       9    0            6.25          3
# 4            0         5      2796       6    0            3.75          3
# ...        ...       ...       ...     ...  ...             ...        ...
# 79442     6348        10      1238       6    0            1.25          5
# 79443     6348        11       985       7    0            2.25          5
# 79444     6348        12      3147      10    0            3.00          5
# 79445     6348        13      1982       8    0            2.50          3
# 79446     6348        14      3491      11    0            4.25          3
#
# ...

# %%
addJockeyRecord()
addGoingType()
addGoingTypeRecord()
oneHotEncodeRunVal("horse_type")
oneHotEncodeRunVal("horse_country")
addWeightDifference()
scaleWeights()
addWinPercent()
addTimeForDistance()
addHorseRaces()
# Out:
# Adding jockey record ...
# 0/79447 (0.000%)
# 5000/79447 (6.294%)
# 10000/79447 (12.587%)
# 15000/79447 (18.881%)
# 20000/79447 (25.174%)
# 25000/79447 (31.468%)
# 30000/79447 (37.761%)
# 35000/79447 (44.055%)
# 40000/79447 (50.348%)
# 45000/79447 (56.642%)
# 50000/79447 (62.935%)
# 55000/79447 (69.229%)
# 60000/79447 (75.522%)
# 65000/79447 (81.816%)
# 70000/79447 (88.109%)
# 75000/79447 (94.403%)
# Adding going type ...
# 0/79447 (0.000%)
# 5000/79447 (6.294%)
# 10000/79447 (12.587%)
# 15000/79447 (18.881%)
# 20000/79447 (25.174%)
# 25000/79447 (31.468%)
# 30000/79447 (37.761%)
# 35000/79447 (44.055%)
# 40000/79447 (50.348%)
# 45000/79447 (56.642%)
# 50000/79447 (62.935%)
# 55000/79447 (69.229%)
# 60000/79447 (75.522%)
# 65000/79447 (81.816%)
# 70000/79447 (88.109%)
# 75000/79447 (94.403%)
# Adding going record ...
# 0/79447 (0.000%)
# 5000/79447 (6.294%)
# 10000/79447 (12.587%)
# 15000/79447 (18.881%)
# 20000/79447 (25.174%)
# 25000/79447 (31.468%)
# 30000/79447 (37.761%)
# ...

# %%
runs.columns
# Out:
# Index(['race_id', 'horse_no', 'horse_id', 'result', 'won', 'lengths_behind',
#        'horse_age', 'horse_country', 'horse_type', 'horse_rating',
#        'horse_gear', 'declared_weight', 'actual_weight', 'draw',
#        'position_sec1', 'position_sec2', 'position_sec3', 'position_sec4',
#        'position_sec5', 'position_sec6', 'behind_sec1', 'behind_sec2',
#        'behind_sec3', 'behind_sec4', 'behind_sec5', 'behind_sec6', 'time1',
#        'time2', 'time3', 'time4', 'time5', 'time6', 'finish_time', 'win_odds',
#        'place_odds', 'trainer_id', 'jockey_id', 'jockey_record', 'going_type',
#        'going_type_record', 'horse_type_Brown', 'horse_type_Colt',
#        'horse_type_Filly', 'horse_type_Gelding', 'horse_type_Grey',
#        'horse_type_Horse', 'horse_type_Mare', 'horse_type_Rig',
#        'horse_type_Roan', 'horse_country_ARG', 'horse_country_AUS',
#        'horse_country_BRZ', 'horse_country_CAN', 'horse_country_FR',
# ...

# %%
runs.to_csv("runs_1.csv", index=False)
