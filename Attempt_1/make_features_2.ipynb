# %%
from feature_functions import *
# USES THE MAIN TO ADD FEATURES

# %%
# Add more columns
# addLastRaceResult()
# runs.to_pickle("Data/main_1.df")
# addWinPercent()
# runs.to_pickle("Data/main_1.df")
#addTimeForDistanceAndNormalized()
# runs.to_pickle("Data/main_1.df")
# addGoingType()
# runs.to_pickle("Data/main_1.df")
# addGoingTypeRecord()
# runs.to_pickle("Data/main_1.df")
# addScaledWeights()
# runs.to_pickle("Data/main_1.df")
# fillPlaceOdds()
# runs.to_pickle("Data/main_1.df")
# addHorseRaces()
# runs.to_pickle("Data/main_1.df")
# oneHotEncodeRunVal("horse_type")
# runs.to_pickle("Data/main_1.df")
# oneHotEncodeRunVal("horse_country")
# runs.to_pickle("Data/main_1.df")
# oneHotEncodeRunVal("going_type")
# runs.to_pickle("Data/main_1.df")
# fillPlaceOdds()
# runs.to_pickle("Data/main_1.df")
# addJockeyRecord()
# runs.to_pickle("Data/main_1.df")
# addTrainerRecord()
# runs.to_pickle("Data/main_1.df")
# addHorseRecord()
# runs.to_pickle("Data/main_1.df")
# addDaysSinceLastRun()
# runs.to_pickle("Data/main_1.df")
#addWeightChange()
#runs.to_pickle("Data/main_1.df")
#addNormalizedResult()
#runs.to_pickle("Data/main_1.df")
#addVenueStats()
#runs.to_pickle("Data/main_1.df")
#addRaceStats()
#runs.to_pickle("Data/main_1.df")
#addNewHorse()
#runs.to_pickle("Data/main_1.df")
#addStartSpeed()
#runs.to_pickle("Data/main_1.df")
addSurfaceRecord()
runs.to_pickle("Data/main_1.df")
#addJockeyRiddenHorse()
#runs.to_pickle("Data/main_1.df")
#addDidPlace()
#runs.to_pickle("Data/main_1.df")
# Out:
# 0/79447 (0.000%)
# 5000/79447 (6.294%)
# 10000/79447 (12.587%)
# 15000/79447 (18.881%)
# 20000/79447 (25.174%)
# 25000/79447 (31.468%)
# 30000/79447 (37.761%)
# 35000/79447 (44.055%)
# 40000/79447 (50.348%)
# 45000/79447 (56.642%)
# 50000/79447 (62.935%)
# 55000/79447 (69.229%)
# 60000/79447 (75.522%)
# 65000/79447 (81.816%)
# 70000/79447 (88.109%)
# 75000/79447 (94.403%)

# %%
for col in runs.columns:
    
    print(col)
# Out:
# race_id
# horse_no
# horse_id
# result
# won
# lengths_behind
# horse_age
# horse_country
# horse_type
# horse_rating
# horse_gear
# declared_weight
# actual_weight
# draw
# position_sec1
# position_sec2
# position_sec3
# position_sec4
# position_sec5
# position_sec6
# behind_sec1
# behind_sec2
# behind_sec3
# behind_sec4
# behind_sec5
# behind_sec6
# time1
# time2
# time3
# time4
# time5
# time6
# finish_time
# win_odds
# place_odds
# trainer_id
# jockey_id
# race_size
# date
# venue
# race_no
# distance
# going
# config
# horse_ratings
# prize
# race_class
# place_combination1
# place_combination2
# place_combination3
# place_combination4
# last_race_result
# win_percent
# avg_distance_time
# normal_avg_distance_time
# going_type
# going_type_record
# actual_weight_scaled
# declared_weight_scaled
# horse_race_count
# horse_type_Brown
# horse_type_Colt
# horse_type_Filly
# horse_type_Gelding
# horse_type_Grey
# horse_type_Horse
# horse_type_Mare
# horse_type_Rig
# horse_type_Roan
# ...

# %%
runs.head(20)
# Out:
#     race_id  horse_no  horse_id  result  won  lengths_behind  horse_age  \
# 0         0         1      3917      10    0            8.00          3
# 1         0         2      2157       8    0            5.75          3
# 2         0         3       858       7    0            4.75          3
# 3         0         4      1853       9    0            6.25          3
# 4         0         5      2796       6    0            3.75          3
# 5         0         6      3296       3    0            1.25          3
# 6         0         7       911      12    0            9.50          3
# 7         0         8      2170       1    1            0.00          3
# 8         0         9      1730      13    0            9.75          3
# 9         0        10      2998      14    0          999.00          3
# 10        0        11      1733       2    0            0.75          3
# 11        0        12      2617       4    0            2.25          3
# ...

# %%
runs.columns[runs.isnull().any()]
# Out:
# Index(['horse_country', 'horse_type', 'position_sec4', 'position_sec5',
#        'position_sec6', 'behind_sec4', 'behind_sec5', 'behind_sec6', 'time4',
#        'time5', 'time6', 'prize', 'place_combination3', 'place_combination4'],
#       dtype='object')

# %%
len(runs.loc[runs["rode_before"]==0])
#len(runs.loc[runs["rode_before"]==1])
# Out:
# 33102

# %%
runs.head(30)
# Out:
#     race_id  horse_no  horse_id  result  won  lengths_behind  horse_age  \
# 0         0         1      3917      10    0            8.00          3
# 1         0         2      2157       8    0            5.75          3
# 2         0         3       858       7    0            4.75          3
# 3         0         4      1853       9    0            6.25          3
# 4         0         5      2796       6    0            3.75          3
# 5         0         6      3296       3    0            1.25          3
# 6         0         7       911      12    0            9.50          3
# 7         0         8      2170       1    1            0.00          3
# 8         0         9      1730      13    0            9.75          3
# 9         0        10      2998      14    0          999.00          3
# 10        0        11      1733       2    0            0.75          3
# 11        0        12      2617       4    0            2.25          3
# ...
